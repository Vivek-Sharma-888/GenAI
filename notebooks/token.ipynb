# %%
import tiktoken

tokenizer = tiktoken.encoding_for_model(model_name="gpt-4")
tokenIds =tokenizer.encode("what is this")
tokenIds
# Out:
# [12840, 374, 420]

# %%
reverseToken = tokenizer.decode([12840, 374, 420])
reverseToken
# Out:
# 'what is this'
